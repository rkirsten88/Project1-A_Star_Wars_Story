# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sts

# %%
#films
url_films = "http://swapi.dev/api/films/" 
films_response = requests.get(url_films).json()

#people
url_people = "http://swapi.dev/api/people/" 
people_response = requests.get(url_people).json()

#planets
url_planets = "http://swapi.dev/api/planets/"
planets_response = requests.get(url_planets).json()

#species
url_species = "http://swapi.dev/api/species/" 
species_response = requests.get(url_species).json()

#vehicles
url_vehicles = "http://swapi.dev/api/vehicles/" 
vehicles_response = requests.get(url_vehicles).json()

#starships
url_starships = "http://swapi.dev/api/starships/"
starships_response = requests.get(url_starships).json()

# %%
#films pprint
print(json.dumps(people_response, indent=2, sort_keys=True))
# Out:
# {
#   "count": 82,
#   "next": "http://swapi.dev/api/people/?page=2",
#   "previous": null,
#   "results": [
#     {
#       "birth_year": "19BBY",
#       "created": "2014-12-09T13:50:51.644000Z",
#       "edited": "2014-12-20T21:17:56.891000Z",
#       "eye_color": "blue",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "blond",
#       "height": "172",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "77",
#       "name": "Luke Skywalker",
#       "skin_color": "fair",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/12/",
#         "http://swapi.dev/api/starships/22/"
#       ],
#       "url": "http://swapi.dev/api/people/1/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/14/",
#         "http://swapi.dev/api/vehicles/30/"
#       ]
#     },
#     {
#       "birth_year": "112BBY",
#       "created": "2014-12-10T15:10:51.357000Z",
#       "edited": "2014-12-20T21:17:50.309000Z",
#       "eye_color": "yellow",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "n/a",
#       "hair_color": "n/a",
#       "height": "167",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "75",
#       "name": "C-3PO",
#       "skin_color": "gold",
#       "species": [
#         "http://swapi.dev/api/species/2/"
#       ],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/2/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "33BBY",
#       "created": "2014-12-10T15:11:50.376000Z",
#       "edited": "2014-12-20T21:17:50.311000Z",
#       "eye_color": "red",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "n/a",
#       "hair_color": "n/a",
#       "height": "96",
#       "homeworld": "http://swapi.dev/api/planets/8/",
#       "mass": "32",
#       "name": "R2-D2",
#       "skin_color": "white, blue",
#       "species": [
#         "http://swapi.dev/api/species/2/"
#       ],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/3/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "41.9BBY",
#       "created": "2014-12-10T15:18:20.704000Z",
#       "edited": "2014-12-20T21:17:50.313000Z",
#       "eye_color": "yellow",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "none",
#       "height": "202",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "136",
#       "name": "Darth Vader",
#       "skin_color": "white",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/13/"
#       ],
#       "url": "http://swapi.dev/api/people/4/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "19BBY",
#       "created": "2014-12-10T15:20:09.791000Z",
#       "edited": "2014-12-20T21:17:50.315000Z",
#       "eye_color": "brown",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "female",
#       "hair_color": "brown",
#       "height": "150",
#       "homeworld": "http://swapi.dev/api/planets/2/",
#       "mass": "49",
#       "name": "Leia Organa",
#       "skin_color": "light",
#       "species": [],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/5/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/30/"
#       ]
#     },
#     {
#       "birth_year": "52BBY",
#       "created": "2014-12-10T15:52:14.024000Z",
#       "edited": "2014-12-20T21:17:50.317000Z",
#       "eye_color": "blue",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "brown, grey",
#       "height": "178",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "120",
#       "name": "Owen Lars",
#       "skin_color": "light",
#       "species": [],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/6/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "47BBY",
#       "created": "2014-12-10T15:53:41.121000Z",
#       "edited": "2014-12-20T21:17:50.319000Z",
#       "eye_color": "blue",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "female",
#       "hair_color": "brown",
#       "height": "165",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "75",
#       "name": "Beru Whitesun lars",
#       "skin_color": "light",
#       "species": [],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/7/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "unknown",
#       "created": "2014-12-10T15:57:50.959000Z",
#       "edited": "2014-12-20T21:17:50.321000Z",
#       "eye_color": "red",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "gender": "n/a",
#       "hair_color": "n/a",
#       "height": "97",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "32",
#       "name": "R5-D4",
#       "skin_color": "white, red",
#       "species": [
#         "http://swapi.dev/api/species/2/"
#       ],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/8/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "24BBY",
#       "created": "2014-12-10T15:59:50.509000Z",
#       "edited": "2014-12-20T21:17:50.323000Z",
#       "eye_color": "brown",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "gender": "male",
#       "hair_color": "black",
#       "height": "183",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "84",
#       "name": "Biggs Darklighter",
#       "skin_color": "light",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/12/"
#       ],
#       "url": "http://swapi.dev/api/people/9/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "57BBY",
#       "created": "2014-12-10T16:16:29.192000Z",
#       "edited": "2014-12-20T21:17:50.325000Z",
#       "eye_color": "blue-gray",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "auburn, white",
#       "height": "182",
#       "homeworld": "http://swapi.dev/api/planets/20/",
#       "mass": "77",
#       "name": "Obi-Wan Kenobi",
#       "skin_color": "fair",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/48/",
#         "http://swapi.dev/api/starships/59/",
#         "http://swapi.dev/api/starships/64/",
#         "http://swapi.dev/api/starships/65/",
#         "http://swapi.dev/api/starships/74/"
#       ],
#       "url": "http://swapi.dev/api/people/10/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/38/"
#       ]
#     }
#   ]
# }

# %%
print(json.dumps(films_response["results"], indent=2, sort_keys=True))
# Out:
# [
#   {
#     "characters": [
#       "http://swapi.dev/api/people/1/",
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/4/",
#       "http://swapi.dev/api/people/5/",
#       "http://swapi.dev/api/people/6/",
#       "http://swapi.dev/api/people/7/",
#       "http://swapi.dev/api/people/8/",
#       "http://swapi.dev/api/people/9/",
#       "http://swapi.dev/api/people/10/",
#       "http://swapi.dev/api/people/12/",
#       "http://swapi.dev/api/people/13/",
#       "http://swapi.dev/api/people/14/",
#       "http://swapi.dev/api/people/15/",
#       "http://swapi.dev/api/people/16/",
#       "http://swapi.dev/api/people/18/",
#       "http://swapi.dev/api/people/19/",
#       "http://swapi.dev/api/people/81/"
#     ],
#     "created": "2014-12-10T14:23:31.880000Z",
#     "director": "George Lucas",
#     "edited": "2014-12-20T19:49:45.256000Z",
#     "episode_id": 4,
#     "opening_crawl": "It is a period of civil war.\r\nRebel spaceships, striking\r\nfrom a hidden base, have won\r\ntheir first victory against\r\nthe evil Galactic Empire.\r\n\r\nDuring the battle, Rebel\r\nspies managed to steal secret\r\nplans to the Empire's\r\nultimate weapon, the DEATH\r\nSTAR, an armored space\r\nstation with enough power\r\nto destroy an entire planet.\r\n\r\nPursued by the Empire's\r\nsinister agents, Princess\r\nLeia races home aboard her\r\nstarship, custodian of the\r\nstolen plans that can save her\r\npeople and restore\r\nfreedom to the galaxy....",
#     "planets": [
#       "http://swapi.dev/api/planets/1/",
#       "http://swapi.dev/api/planets/2/",
#       "http://swapi.dev/api/planets/3/"
#     ],
#     "producer": "Gary Kurtz, Rick McCallum",
#     "release_date": "1977-05-25",
#     "species": [
#       "http://swapi.dev/api/species/1/",
#       "http://swapi.dev/api/species/2/",
#       "http://swapi.dev/api/species/3/",
#       "http://swapi.dev/api/species/4/",
#       "http://swapi.dev/api/species/5/"
#     ],
#     "starships": [
#       "http://swapi.dev/api/starships/2/",
#       "http://swapi.dev/api/starships/3/",
#       "http://swapi.dev/api/starships/5/",
#       "http://swapi.dev/api/starships/9/",
#       "http://swapi.dev/api/starships/10/",
#       "http://swapi.dev/api/starships/11/",
#       "http://swapi.dev/api/starships/12/",
#       "http://swapi.dev/api/starships/13/"
#     ],
#     "title": "A New Hope",
#     "url": "http://swapi.dev/api/films/1/",
#     "vehicles": [
#       "http://swapi.dev/api/vehicles/4/",
#       "http://swapi.dev/api/vehicles/6/",
#       "http://swapi.dev/api/vehicles/7/",
#       "http://swapi.dev/api/vehicles/8/"
#     ]
#   },
#   {
#     "characters": [
#       "http://swapi.dev/api/people/1/",
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/4/",
#       "http://swapi.dev/api/people/5/",
#       "http://swapi.dev/api/people/10/",
#       "http://swapi.dev/api/people/13/",
#       "http://swapi.dev/api/people/14/",
#       "http://swapi.dev/api/people/18/",
#       "http://swapi.dev/api/people/20/",
#       "http://swapi.dev/api/people/21/",
#       "http://swapi.dev/api/people/22/",
#       "http://swapi.dev/api/people/23/",
#       "http://swapi.dev/api/people/24/",
#       "http://swapi.dev/api/people/25/",
#       "http://swapi.dev/api/people/26/"
#     ],
#     "created": "2014-12-12T11:26:24.656000Z",
#     "director": "Irvin Kershner",
#     "edited": "2014-12-15T13:07:53.386000Z",
#     "episode_id": 5,
#     "opening_crawl": "It is a dark time for the\r\nRebellion. Although the Death\r\nStar has been destroyed,\r\nImperial troops have driven the\r\nRebel forces from their hidden\r\nbase and pursued them across\r\nthe galaxy.\r\n\r\nEvading the dreaded Imperial\r\nStarfleet, a group of freedom\r\nfighters led by Luke Skywalker\r\nhas established a new secret\r\nbase on the remote ice world\r\nof Hoth.\r\n\r\nThe evil lord Darth Vader,\r\nobsessed with finding young\r\nSkywalker, has dispatched\r\nthousands of remote probes into\r\nthe far reaches of space....",
#     "planets": [
#       "http://swapi.dev/api/planets/4/",
#       "http://swapi.dev/api/planets/5/",
#       "http://swapi.dev/api/planets/6/",
#       "http://swapi.dev/api/planets/27/"
#     ],
#     "producer": "Gary Kurtz, Rick McCallum",
#     "release_date": "1980-05-17",
#     "species": [
#       "http://swapi.dev/api/species/1/",
#       "http://swapi.dev/api/species/2/",
#       "http://swapi.dev/api/species/3/",
#       "http://swapi.dev/api/species/6/",
#       "http://swapi.dev/api/species/7/"
#     ],
#     "starships": [
#       "http://swapi.dev/api/starships/3/",
#       "http://swapi.dev/api/starships/10/",
#       "http://swapi.dev/api/starships/11/",
#       "http://swapi.dev/api/starships/12/",
#       "http://swapi.dev/api/starships/15/",
#       "http://swapi.dev/api/starships/17/",
#       "http://swapi.dev/api/starships/21/",
#       "http://swapi.dev/api/starships/22/",
#       "http://swapi.dev/api/starships/23/"
#     ],
#     "title": "The Empire Strikes Back",
#     "url": "http://swapi.dev/api/films/2/",
#     "vehicles": [
#       "http://swapi.dev/api/vehicles/8/",
#       "http://swapi.dev/api/vehicles/14/",
#       "http://swapi.dev/api/vehicles/16/",
#       "http://swapi.dev/api/vehicles/18/",
#       "http://swapi.dev/api/vehicles/19/",
#       "http://swapi.dev/api/vehicles/20/"
#     ]
#   },
#   {
#     "characters": [
#       "http://swapi.dev/api/people/1/",
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/4/",
#       "http://swapi.dev/api/people/5/",
#       "http://swapi.dev/api/people/10/",
#       "http://swapi.dev/api/people/13/",
#       "http://swapi.dev/api/people/14/",
#       "http://swapi.dev/api/people/16/",
#       "http://swapi.dev/api/people/18/",
#       "http://swapi.dev/api/people/20/",
#       "http://swapi.dev/api/people/21/",
#       "http://swapi.dev/api/people/22/",
#       "http://swapi.dev/api/people/25/",
#       "http://swapi.dev/api/people/27/",
#       "http://swapi.dev/api/people/28/",
#       "http://swapi.dev/api/people/29/",
#       "http://swapi.dev/api/people/30/",
#       "http://swapi.dev/api/people/31/",
#       "http://swapi.dev/api/people/45/"
#     ],
#     "created": "2014-12-18T10:39:33.255000Z",
#     "director": "Richard Marquand",
#     "edited": "2014-12-20T09:48:37.462000Z",
#     "episode_id": 6,
#     "opening_crawl": "Luke Skywalker has returned to\r\nhis home planet of Tatooine in\r\nan attempt to rescue his\r\nfriend Han Solo from the\r\nclutches of the vile gangster\r\nJabba the Hutt.\r\n\r\nLittle does Luke know that the\r\nGALACTIC EMPIRE has secretly\r\nbegun construction on a new\r\narmored space station even\r\nmore powerful than the first\r\ndreaded Death Star.\r\n\r\nWhen completed, this ultimate\r\nweapon will spell certain doom\r\nfor the small band of rebels\r\nstruggling to restore freedom\r\nto the galaxy...",
#     "planets": [
#       "http://swapi.dev/api/planets/1/",
#       "http://swapi.dev/api/planets/5/",
#       "http://swapi.dev/api/planets/7/",
#       "http://swapi.dev/api/planets/8/",
#       "http://swapi.dev/api/planets/9/"
#     ],
#     "producer": "Howard G. Kazanjian, George Lucas, Rick McCallum",
#     "release_date": "1983-05-25",
#     "species": [
#       "http://swapi.dev/api/species/1/",
#       "http://swapi.dev/api/species/2/",
#       "http://swapi.dev/api/species/3/",
#       "http://swapi.dev/api/species/5/",
#       "http://swapi.dev/api/species/6/",
#       "http://swapi.dev/api/species/8/",
#       "http://swapi.dev/api/species/9/",
#       "http://swapi.dev/api/species/10/",
#       "http://swapi.dev/api/species/15/"
#     ],
#     "starships": [
#       "http://swapi.dev/api/starships/2/",
#       "http://swapi.dev/api/starships/3/",
#       "http://swapi.dev/api/starships/10/",
#       "http://swapi.dev/api/starships/11/",
#       "http://swapi.dev/api/starships/12/",
#       "http://swapi.dev/api/starships/15/",
#       "http://swapi.dev/api/starships/17/",
#       "http://swapi.dev/api/starships/22/",
#       "http://swapi.dev/api/starships/23/",
#       "http://swapi.dev/api/starships/27/",
#       "http://swapi.dev/api/starships/28/",
#       "http://swapi.dev/api/starships/29/"
#     ],
#     "title": "Return of the Jedi",
#     "url": "http://swapi.dev/api/films/3/",
#     "vehicles": [
#       "http://swapi.dev/api/vehicles/8/",
#       "http://swapi.dev/api/vehicles/16/",
#       "http://swapi.dev/api/vehicles/18/",
#       "http://swapi.dev/api/vehicles/19/",
#       "http://swapi.dev/api/vehicles/24/",
#       "http://swapi.dev/api/vehicles/25/",
#       "http://swapi.dev/api/vehicles/26/",
#       "http://swapi.dev/api/vehicles/30/"
#     ]
#   },
#   {
#     "characters": [
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/10/",
#       "http://swapi.dev/api/people/11/",
#       "http://swapi.dev/api/people/16/",
#       "http://swapi.dev/api/people/20/",
#       "http://swapi.dev/api/people/21/",
#       "http://swapi.dev/api/people/32/",
#       "http://swapi.dev/api/people/33/",
#       "http://swapi.dev/api/people/34/",
#       "http://swapi.dev/api/people/35/",
#       "http://swapi.dev/api/people/36/",
#       "http://swapi.dev/api/people/37/",
#       "http://swapi.dev/api/people/38/",
#       "http://swapi.dev/api/people/39/",
#       "http://swapi.dev/api/people/40/",
#       "http://swapi.dev/api/people/41/",
#       "http://swapi.dev/api/people/42/",
#       "http://swapi.dev/api/people/43/",
#       "http://swapi.dev/api/people/44/",
#       "http://swapi.dev/api/people/46/",
#       "http://swapi.dev/api/people/47/",
#       "http://swapi.dev/api/people/48/",
#       "http://swapi.dev/api/people/49/",
#       "http://swapi.dev/api/people/50/",
#       "http://swapi.dev/api/people/51/",
#       "http://swapi.dev/api/people/52/",
#       "http://swapi.dev/api/people/53/",
#       "http://swapi.dev/api/people/54/",
#       "http://swapi.dev/api/people/55/",
#       "http://swapi.dev/api/people/56/",
#       "http://swapi.dev/api/people/57/",
#       "http://swapi.dev/api/people/58/",
#       "http://swapi.dev/api/people/59/"
#     ],
#     "created": "2014-12-19T16:52:55.740000Z",
#     "director": "George Lucas",
#     "edited": "2014-12-20T10:54:07.216000Z",
#     "episode_id": 1,
#     "opening_crawl": "Turmoil has engulfed the\r\nGalactic Republic. The taxation\r\nof trade routes to outlying star\r\nsystems is in dispute.\r\n\r\nHoping to resolve the matter\r\nwith a blockade of deadly\r\nbattleships, the greedy Trade\r\nFederation has stopped all\r\nshipping to the small planet\r\nof Naboo.\r\n\r\nWhile the Congress of the\r\nRepublic endlessly debates\r\nthis alarming chain of events,\r\nthe Supreme Chancellor has\r\nsecretly dispatched two Jedi\r\nKnights, the guardians of\r\npeace and justice in the\r\ngalaxy, to settle the conflict....",
#     "planets": [
#       "http://swapi.dev/api/planets/1/",
#       "http://swapi.dev/api/planets/8/",
#       "http://swapi.dev/api/planets/9/"
#     ],
#     "producer": "Rick McCallum",
#     "release_date": "1999-05-19",
#     "species": [
#       "http://swapi.dev/api/species/1/",
#       "http://swapi.dev/api/species/2/",
#       "http://swapi.dev/api/species/6/",
#       "http://swapi.dev/api/species/11/",
#       "http://swapi.dev/api/species/12/",
#       "http://swapi.dev/api/species/13/",
#       "http://swapi.dev/api/species/14/",
#       "http://swapi.dev/api/species/15/",
#       "http://swapi.dev/api/species/16/",
#       "http://swapi.dev/api/species/17/",
#       "http://swapi.dev/api/species/18/",
#       "http://swapi.dev/api/species/19/",
#       "http://swapi.dev/api/species/20/",
#       "http://swapi.dev/api/species/21/",
#       "http://swapi.dev/api/species/22/",
#       "http://swapi.dev/api/species/23/",
#       "http://swapi.dev/api/species/24/",
#       "http://swapi.dev/api/species/25/",
#       "http://swapi.dev/api/species/26/",
#       "http://swapi.dev/api/species/27/"
#     ],
#     "starships": [
#       "http://swapi.dev/api/starships/31/",
#       "http://swapi.dev/api/starships/32/",
#       "http://swapi.dev/api/starships/39/",
#       "http://swapi.dev/api/starships/40/",
#       "http://swapi.dev/api/starships/41/"
#     ],
#     "title": "The Phantom Menace",
#     "url": "http://swapi.dev/api/films/4/",
#     "vehicles": [
#       "http://swapi.dev/api/vehicles/33/",
#       "http://swapi.dev/api/vehicles/34/",
#       "http://swapi.dev/api/vehicles/35/",
#       "http://swapi.dev/api/vehicles/36/",
#       "http://swapi.dev/api/vehicles/37/",
#       "http://swapi.dev/api/vehicles/38/",
#       "http://swapi.dev/api/vehicles/42/"
#     ]
#   },
#   {
#     "characters": [
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/6/",
#       "http://swapi.dev/api/people/7/",
#       "http://swapi.dev/api/people/10/",
#       "http://swapi.dev/api/people/11/",
#       "http://swapi.dev/api/people/20/",
#       "http://swapi.dev/api/people/21/",
#       "http://swapi.dev/api/people/22/",
#       "http://swapi.dev/api/people/33/",
#       "http://swapi.dev/api/people/35/",
#       "http://swapi.dev/api/people/36/",
#       "http://swapi.dev/api/people/40/",
#       "http://swapi.dev/api/people/43/",
#       "http://swapi.dev/api/people/46/",
#       "http://swapi.dev/api/people/51/",
#       "http://swapi.dev/api/people/52/",
#       "http://swapi.dev/api/people/53/",
#       "http://swapi.dev/api/people/58/",
#       "http://swapi.dev/api/people/59/",
#       "http://swapi.dev/api/people/60/",
#       "http://swapi.dev/api/people/61/",
#       "http://swapi.dev/api/people/62/",
#       "http://swapi.dev/api/people/63/",
#       "http://swapi.dev/api/people/64/",
#       "http://swapi.dev/api/people/65/",
#       "http://swapi.dev/api/people/66/",
#       "http://swapi.dev/api/people/67/",
#       "http://swapi.dev/api/people/68/",
#       "http://swapi.dev/api/people/69/",
#       "http://swapi.dev/api/people/70/",
#       "http://swapi.dev/api/people/71/",
#       "http://swapi.dev/api/people/72/",
#       "http://swapi.dev/api/people/73/",
#       "http://swapi.dev/api/people/74/",
#       "http://swapi.dev/api/people/75/",
#       "http://swapi.dev/api/people/76/",
#       "http://swapi.dev/api/people/77/",
#       "http://swapi.dev/api/people/78/",
#       "http://swapi.dev/api/people/82/"
#     ],
#     "created": "2014-12-20T10:57:57.886000Z",
#     "director": "George Lucas",
#     "edited": "2014-12-20T20:18:48.516000Z",
#     "episode_id": 2,
#     "opening_crawl": "There is unrest in the Galactic\r\nSenate. Several thousand solar\r\nsystems have declared their\r\nintentions to leave the Republic.\r\n\r\nThis separatist movement,\r\nunder the leadership of the\r\nmysterious Count Dooku, has\r\nmade it difficult for the limited\r\nnumber of Jedi Knights to maintain \r\npeace and order in the galaxy.\r\n\r\nSenator Amidala, the former\r\nQueen of Naboo, is returning\r\nto the Galactic Senate to vote\r\non the critical issue of creating\r\nan ARMY OF THE REPUBLIC\r\nto assist the overwhelmed\r\nJedi....",
#     "planets": [
#       "http://swapi.dev/api/planets/1/",
#       "http://swapi.dev/api/planets/8/",
#       "http://swapi.dev/api/planets/9/",
#       "http://swapi.dev/api/planets/10/",
#       "http://swapi.dev/api/planets/11/"
#     ],
#     "producer": "Rick McCallum",
#     "release_date": "2002-05-16",
#     "species": [
#       "http://swapi.dev/api/species/1/",
#       "http://swapi.dev/api/species/2/",
#       "http://swapi.dev/api/species/6/",
#       "http://swapi.dev/api/species/12/",
#       "http://swapi.dev/api/species/13/",
#       "http://swapi.dev/api/species/15/",
#       "http://swapi.dev/api/species/28/",
#       "http://swapi.dev/api/species/29/",
#       "http://swapi.dev/api/species/30/",
#       "http://swapi.dev/api/species/31/",
#       "http://swapi.dev/api/species/32/",
#       "http://swapi.dev/api/species/33/",
#       "http://swapi.dev/api/species/34/",
#       "http://swapi.dev/api/species/35/"
#     ],
#     "starships": [
#       "http://swapi.dev/api/starships/21/",
#       "http://swapi.dev/api/starships/32/",
#       "http://swapi.dev/api/starships/39/",
#       "http://swapi.dev/api/starships/43/",
#       "http://swapi.dev/api/starships/47/",
#       "http://swapi.dev/api/starships/48/",
#       "http://swapi.dev/api/starships/49/",
#       "http://swapi.dev/api/starships/52/",
#       "http://swapi.dev/api/starships/58/"
#     ],
#     "title": "Attack of the Clones",
#     "url": "http://swapi.dev/api/films/5/",
#     "vehicles": [
#       "http://swapi.dev/api/vehicles/4/",
#       "http://swapi.dev/api/vehicles/44/",
#       "http://swapi.dev/api/vehicles/45/",
#       "http://swapi.dev/api/vehicles/46/",
#       "http://swapi.dev/api/vehicles/50/",
#       "http://swapi.dev/api/vehicles/51/",
#       "http://swapi.dev/api/vehicles/53/",
#       "http://swapi.dev/api/vehicles/54/",
#       "http://swapi.dev/api/vehicles/55/",
#       "http://swapi.dev/api/vehicles/56/",
#       "http://swapi.dev/api/vehicles/57/"
#     ]
#   },
#   {
#     "characters": [
#       "http://swapi.dev/api/people/1/",
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/4/",
#       "http://swapi.dev/api/people/5/",
#       "http://swapi.dev/api/people/6/",
#       "http://swapi.dev/api/people/7/",
#       "http://swapi.dev/api/people/10/",
#       "http://swapi.dev/api/people/11/",
#       "http://swapi.dev/api/people/12/",
#       "http://swapi.dev/api/people/13/",
#       "http://swapi.dev/api/people/20/",
#       "http://swapi.dev/api/people/21/",
#       "http://swapi.dev/api/people/33/",
#       "http://swapi.dev/api/people/35/",
#       "http://swapi.dev/api/people/46/",
#       "http://swapi.dev/api/people/51/",
#       "http://swapi.dev/api/people/52/",
#       "http://swapi.dev/api/people/53/",
#       "http://swapi.dev/api/people/54/",
#       "http://swapi.dev/api/people/55/",
#       "http://swapi.dev/api/people/56/",
#       "http://swapi.dev/api/people/58/",
#       "http://swapi.dev/api/people/63/",
#       "http://swapi.dev/api/people/64/",
#       "http://swapi.dev/api/people/67/",
#       "http://swapi.dev/api/people/68/",
#       "http://swapi.dev/api/people/75/",
#       "http://swapi.dev/api/people/78/",
#       "http://swapi.dev/api/people/79/",
#       "http://swapi.dev/api/people/80/",
#       "http://swapi.dev/api/people/81/",
#       "http://swapi.dev/api/people/82/",
#       "http://swapi.dev/api/people/83/"
#     ],
#     "created": "2014-12-20T18:49:38.403000Z",
#     "director": "George Lucas",
#     "edited": "2014-12-20T20:47:52.073000Z",
#     "episode_id": 3,
#     "opening_crawl": "War! The Republic is crumbling\r\nunder attacks by the ruthless\r\nSith Lord, Count Dooku.\r\nThere are heroes on both sides.\r\nEvil is everywhere.\r\n\r\nIn a stunning move, the\r\nfiendish droid leader, General\r\nGrievous, has swept into the\r\nRepublic capital and kidnapped\r\nChancellor Palpatine, leader of\r\nthe Galactic Senate.\r\n\r\nAs the Separatist Droid Army\r\nattempts to flee the besieged\r\ncapital with their valuable\r\nhostage, two Jedi Knights lead a\r\ndesperate mission to rescue the\r\ncaptive Chancellor....",
#     "planets": [
#       "http://swapi.dev/api/planets/1/",
#       "http://swapi.dev/api/planets/2/",
#       "http://swapi.dev/api/planets/5/",
#       "http://swapi.dev/api/planets/8/",
#       "http://swapi.dev/api/planets/9/",
#       "http://swapi.dev/api/planets/12/",
#       "http://swapi.dev/api/planets/13/",
#       "http://swapi.dev/api/planets/14/",
#       "http://swapi.dev/api/planets/15/",
#       "http://swapi.dev/api/planets/16/",
#       "http://swapi.dev/api/planets/17/",
#       "http://swapi.dev/api/planets/18/",
#       "http://swapi.dev/api/planets/19/"
#     ],
#     "producer": "Rick McCallum",
#     "release_date": "2005-05-19",
#     "species": [
#       "http://swapi.dev/api/species/1/",
#       "http://swapi.dev/api/species/2/",
#       "http://swapi.dev/api/species/3/",
#       "http://swapi.dev/api/species/6/",
#       "http://swapi.dev/api/species/15/",
#       "http://swapi.dev/api/species/19/",
#       "http://swapi.dev/api/species/20/",
#       "http://swapi.dev/api/species/23/",
#       "http://swapi.dev/api/species/24/",
#       "http://swapi.dev/api/species/25/",
#       "http://swapi.dev/api/species/26/",
#       "http://swapi.dev/api/species/27/",
#       "http://swapi.dev/api/species/28/",
#       "http://swapi.dev/api/species/29/",
#       "http://swapi.dev/api/species/30/",
#       "http://swapi.dev/api/species/33/",
#       "http://swapi.dev/api/species/34/",
#       "http://swapi.dev/api/species/35/",
#       "http://swapi.dev/api/species/36/",
#       "http://swapi.dev/api/species/37/"
#     ],
#     "starships": [
#       "http://swapi.dev/api/starships/2/",
#       "http://swapi.dev/api/starships/32/",
#       "http://swapi.dev/api/starships/48/",
#       "http://swapi.dev/api/starships/59/",
#       "http://swapi.dev/api/starships/61/",
#       "http://swapi.dev/api/starships/63/",
#       "http://swapi.dev/api/starships/64/",
#       "http://swapi.dev/api/starships/65/",
#       "http://swapi.dev/api/starships/66/",
#       "http://swapi.dev/api/starships/68/",
#       "http://swapi.dev/api/starships/74/",
#       "http://swapi.dev/api/starships/75/"
#     ],
#     "title": "Revenge of the Sith",
#     "url": "http://swapi.dev/api/films/6/",
#     "vehicles": [
#       "http://swapi.dev/api/vehicles/33/",
#       "http://swapi.dev/api/vehicles/50/",
#       "http://swapi.dev/api/vehicles/53/",
#       "http://swapi.dev/api/vehicles/56/",
#       "http://swapi.dev/api/vehicles/60/",
#       "http://swapi.dev/api/vehicles/62/",
#       "http://swapi.dev/api/vehicles/67/",
#       "http://swapi.dev/api/vehicles/69/",
#       "http://swapi.dev/api/vehicles/70/",
#       "http://swapi.dev/api/vehicles/71/",
#       "http://swapi.dev/api/vehicles/72/",
#       "http://swapi.dev/api/vehicles/73/",
#       "http://swapi.dev/api/vehicles/76/"
#     ]
#   }
# ]

# %%
character_list = []
page = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
url_people_next = f"http://swapi.dev/api/people/?page="

for x in page:
    people_response_next = requests.get(url_people_next + x).json()
    
#for loop to list names
    for people in people_response_next["results"]:
        character_name = people["name"]
        character_list.append(character_name)
        print(character_name)
# Out:
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Owen Lars
# Beru Whitesun lars
# R5-D4
# Biggs Darklighter
# Obi-Wan Kenobi
# Anakin Skywalker
# Wilhuff Tarkin
# Chewbacca
# Han Solo
# Greedo
# Jabba Desilijic Tiure
# Wedge Antilles
# Jek Tono Porkins
# Yoda
# Palpatine
# Boba Fett
# IG-88
# Bossk
# Lando Calrissian
# Lobot
# Ackbar
# Mon Mothma
# Arvel Crynyd
# Wicket Systri Warrick
# Nien Nunb
# Qui-Gon Jinn
# Nute Gunray
# Finis Valorum
# Padmé Amidala
# Jar Jar Binks
# Roos Tarpals
# Rugor Nass
# Ric Olié
# Watto
# Sebulba
# Quarsh Panaka
# Shmi Skywalker
# Darth Maul
# Bib Fortuna
# Ayla Secura
# Ratts Tyerel
# Dud Bolt
# Gasgano
# Ben Quadinaros
# Mace Windu
# Ki-Adi-Mundi
# Kit Fisto
# Eeth Koth
# Adi Gallia
# Saesee Tiin
# Yarael Poof
# Plo Koon
# Mas Amedda
# Gregar Typho
# Cordé
# Cliegg Lars
# Poggle the Lesser
# Luminara Unduli
# Barriss Offee
# Dormé
# Dooku
# Bail Prestor Organa
# Jango Fett
# Zam Wesell
# Dexter Jettster
# Lama Su
# Taun We
# Jocasta Nu
# R4-P17
# Wat Tambor
# San Hill
# Shaak Ti
# Grievous
# Tarfful
# Raymus Antilles
# Sly Moore
# Tion Medon

# %%
print(character_list)
# Out:
# ['Luke Skywalker', 'C-3PO', 'R2-D2', 'Darth Vader', 'Leia Organa', 'Owen Lars', 'Beru Whitesun lars', 'R5-D4', 'Biggs Darklighter', 'Obi-Wan Kenobi', 'Anakin Skywalker', 'Wilhuff Tarkin', 'Chewbacca', 'Han Solo', 'Greedo', 'Jabba Desilijic Tiure', 'Wedge Antilles', 'Jek Tono Porkins', 'Yoda', 'Palpatine', 'Boba Fett', 'IG-88', 'Bossk', 'Lando Calrissian', 'Lobot', 'Ackbar', 'Mon Mothma', 'Arvel Crynyd', 'Wicket Systri Warrick', 'Nien Nunb', 'Qui-Gon Jinn', 'Nute Gunray', 'Finis Valorum', 'Padmé Amidala', 'Jar Jar Binks', 'Roos Tarpals', 'Rugor Nass', 'Ric Olié', 'Watto', 'Sebulba', 'Quarsh Panaka', 'Shmi Skywalker', 'Darth Maul', 'Bib Fortuna', 'Ayla Secura', 'Ratts Tyerel', 'Dud Bolt', 'Gasgano', 'Ben Quadinaros', 'Mace Windu', 'Ki-Adi-Mundi', 'Kit Fisto', 'Eeth Koth', 'Adi Gallia', 'Saesee Tiin', 'Yarael Poof', 'Plo Koon', 'Mas Amedda', 'Gregar Typho', 'Cordé', 'Cliegg Lars', 'Poggle the Lesser', 'Luminara Unduli', 'Barriss Offee', 'Dormé', 'Dooku', 'Bail Prestor Organa', 'Jango Fett', 'Zam Wesell', 'Dexter Jettster', 'Lama Su', 'Taun We', 'Jocasta Nu', 'R4-P17', 'Wat Tambor', 'San Hill', 'Shaak Ti', 'Grievous', 'Tarfful', 'Raymus Antilles', 'Sly Moore', 'Tion Medon']

# %%
all_characters = []
m_title = []
for films in films_response["results"]:
    m_title.append(films["title"])
    all_characters.append(films["characters"])

print(m_title)
print(all_characters)

#create a dataframe and merge the info
# Out:
# ['A New Hope', 'The Empire Strikes Back', 'Return of the Jedi', 'The Phantom Menace', 'Attack of the Clones', 'Revenge of the Sith']
# [['http://swapi.dev/api/people/1/', 'http://swapi.dev/api/people/2/', 'http://swapi.dev/api/people/3/', 'http://swapi.dev/api/people/4/', 'http://swapi.dev/api/people/5/', 'http://swapi.dev/api/people/6/', 'http://swapi.dev/api/people/7/', 'http://swapi.dev/api/people/8/', 'http://swapi.dev/api/people/9/', 'http://swapi.dev/api/people/10/', 'http://swapi.dev/api/people/12/', 'http://swapi.dev/api/people/13/', 'http://swapi.dev/api/people/14/', 'http://swapi.dev/api/people/15/', 'http://swapi.dev/api/people/16/', 'http://swapi.dev/api/people/18/', 'http://swapi.dev/api/people/19/', 'http://swapi.dev/api/people/81/'], ['http://swapi.dev/api/people/1/', 'http://swapi.dev/api/people/2/', 'http://swapi.dev/api/people/3/', 'http://swapi.dev/api/people/4/', 'http://swapi.dev/api/people/5/', 'http://swapi.dev/api/people/10/', 'http://swapi.dev/api/people/13/', 'http://swapi.dev/api/people/14/', 'http://swapi.dev/api/people/18/', 'http://swapi.dev/api/people/20/', 'http://swapi.dev/api/people/21/', 'http://swapi.dev/api/people/22/', 'http://swapi.dev/api/people/23/', 'http://swapi.dev/api/people/24/', 'http://swapi.dev/api/people/25/', 'http://swapi.dev/api/people/26/'], ['http://swapi.dev/api/people/1/', 'http://swapi.dev/api/people/2/', 'http://swapi.dev/api/people/3/', 'http://swapi.dev/api/people/4/', 'http://swapi.dev/api/people/5/', 'http://swapi.dev/api/people/10/', 'http://swapi.dev/api/people/13/', 'http://swapi.dev/api/people/14/', 'http://swapi.dev/api/people/16/', 'http://swapi.dev/api/people/18/', 'http://swapi.dev/api/people/20/', 'http://swapi.dev/api/people/21/', 'http://swapi.dev/api/people/22/', 'http://swapi.dev/api/people/25/', 'http://swapi.dev/api/people/27/', 'http://swapi.dev/api/people/28/', 'http://swapi.dev/api/people/29/', 'http://swapi.dev/api/people/30/', 'http://swapi.dev/api/people/31/', 'http://swapi.dev/api/people/45/'], ['http://swapi.dev/api/people/2/', 'http://swapi.dev/api/people/3/', 'http://swapi.dev/api/people/10/', 'http://swapi.dev/api/people/11/', 'http://swapi.dev/api/people/16/', 'http://swapi.dev/api/people/20/', 'http://swapi.dev/api/people/21/', 'http://swapi.dev/api/people/32/', 'http://swapi.dev/api/people/33/', 'http://swapi.dev/api/people/34/', 'http://swapi.dev/api/people/35/', 'http://swapi.dev/api/people/36/', 'http://swapi.dev/api/people/37/', 'http://swapi.dev/api/people/38/', 'http://swapi.dev/api/people/39/', 'http://swapi.dev/api/people/40/', 'http://swapi.dev/api/people/41/', 'http://swapi.dev/api/people/42/', 'http://swapi.dev/api/people/43/', 'http://swapi.dev/api/people/44/', 'http://swapi.dev/api/people/46/', 'http://swapi.dev/api/people/47/', 'http://swapi.dev/api/people/48/', 'http://swapi.dev/api/people/49/', 'http://swapi.dev/api/people/50/', 'http://swapi.dev/api/people/51/', 'http://swapi.dev/api/people/52/', 'http://swapi.dev/api/people/53/', 'http://swapi.dev/api/people/54/', 'http://swapi.dev/api/people/55/', 'http://swapi.dev/api/people/56/', 'http://swapi.dev/api/people/57/', 'http://swapi.dev/api/people/58/', 'http://swapi.dev/api/people/59/'], ['http://swapi.dev/api/people/2/', 'http://swapi.dev/api/people/3/', 'http://swapi.dev/api/people/6/', 'http://swapi.dev/api/people/7/', 'http://swapi.dev/api/people/10/', 'http://swapi.dev/api/people/11/', 'http://swapi.dev/api/people/20/', 'http://swapi.dev/api/people/21/', 'http://swapi.dev/api/people/22/', 'http://swapi.dev/api/people/33/', 'http://swapi.dev/api/people/35/', 'http://swapi.dev/api/people/36/', 'http://swapi.dev/api/people/40/', 'http://swapi.dev/api/people/43/', 'http://swapi.dev/api/people/46/', 'http://swapi.dev/api/people/51/', 'http://swapi.dev/api/people/52/', 'http://swapi.dev/api/people/53/', 'http://swapi.dev/api/people/58/', 'http://swapi.dev/api/people/59/', 'http://swapi.dev/api/people/60/', 'http://swapi.dev/api/people/61/', 'http://swapi.dev/api/people/62/', 'http://swapi.dev/api/people/63/', 'http://swapi.dev/api/people/64/', 'http://swapi.dev/api/people/65/', 'http://swapi.dev/api/peo ...

# %%
people_df = pd.DataFrame({"Title": m_title,
                          "Characters": all_characters})
people_df
# Out:
#                      Title                                         Characters
# 0               A New Hope  [http://swapi.dev/api/people/1/, http://swapi....
# 1  The Empire Strikes Back  [http://swapi.dev/api/people/1/, http://swapi....
# 2       Return of the Jedi  [http://swapi.dev/api/people/1/, http://swapi....
# 3       The Phantom Menace  [http://swapi.dev/api/people/2/, http://swapi....
# 4     Attack of the Clones  [http://swapi.dev/api/people/2/, http://swapi....
# 5      Revenge of the Sith  [http://swapi.dev/api/people/1/, http://swapi....

# %%
people_df=people_df.join(people_df['Characters'].str.split(',', expand=True).add_prefix('Characters'))
people_df
# Out:
#                      Title                                         Characters  \
# 0               A New Hope  [http://swapi.dev/api/people/1/, http://swapi....
# 1  The Empire Strikes Back  [http://swapi.dev/api/people/1/, http://swapi....
# 2       Return of the Jedi  [http://swapi.dev/api/people/1/, http://swapi....
# 3       The Phantom Menace  [http://swapi.dev/api/people/2/, http://swapi....
# 4     Attack of the Clones  [http://swapi.dev/api/people/2/, http://swapi....
# 5      Revenge of the Sith  [http://swapi.dev/api/people/1/, http://swapi....
#
#    Characters0
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN

# %%
for films in films_response["results"]:
    movie_title = films["title"]
    print(movie_title)
# Out:
# A New Hope
# The Empire Strikes Back
# Return of the Jedi
# The Phantom Menace
# Attack of the Clones
# Revenge of the Sith

# %%
#planets pprint
print(json.dumps(planets_response, indent=2, sort_keys=True))
# Out:
# {
#   "count": 60,
#   "next": "http://swapi.dev/api/planets/?page=2",
#   "previous": null,
#   "results": [
#     {
#       "climate": "arid",
#       "created": "2014-12-09T13:50:49.641000Z",
#       "diameter": "10465",
#       "edited": "2014-12-20T20:58:18.411000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gravity": "1 standard",
#       "name": "Tatooine",
#       "orbital_period": "304",
#       "population": "200000",
#       "residents": [
#         "http://swapi.dev/api/people/1/",
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/4/",
#         "http://swapi.dev/api/people/6/",
#         "http://swapi.dev/api/people/7/",
#         "http://swapi.dev/api/people/8/",
#         "http://swapi.dev/api/people/9/",
#         "http://swapi.dev/api/people/11/",
#         "http://swapi.dev/api/people/43/",
#         "http://swapi.dev/api/people/62/"
#       ],
#       "rotation_period": "23",
#       "surface_water": "1",
#       "terrain": "desert",
#       "url": "http://swapi.dev/api/planets/1/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-10T11:35:48.479000Z",
#       "diameter": "12500",
#       "edited": "2014-12-20T20:58:18.420000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gravity": "1 standard",
#       "name": "Alderaan",
#       "orbital_period": "364",
#       "population": "2000000000",
#       "residents": [
#         "http://swapi.dev/api/people/5/",
#         "http://swapi.dev/api/people/68/",
#         "http://swapi.dev/api/people/81/"
#       ],
#       "rotation_period": "24",
#       "surface_water": "40",
#       "terrain": "grasslands, mountains",
#       "url": "http://swapi.dev/api/planets/2/"
#     },
#     {
#       "climate": "temperate, tropical",
#       "created": "2014-12-10T11:37:19.144000Z",
#       "diameter": "10200",
#       "edited": "2014-12-20T20:58:18.421000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "gravity": "1 standard",
#       "name": "Yavin IV",
#       "orbital_period": "4818",
#       "population": "1000",
#       "residents": [],
#       "rotation_period": "24",
#       "surface_water": "8",
#       "terrain": "jungle, rainforests",
#       "url": "http://swapi.dev/api/planets/3/"
#     },
#     {
#       "climate": "frozen",
#       "created": "2014-12-10T11:39:13.934000Z",
#       "diameter": "7200",
#       "edited": "2014-12-20T20:58:18.423000Z",
#       "films": [
#         "http://swapi.dev/api/films/2/"
#       ],
#       "gravity": "1.1 standard",
#       "name": "Hoth",
#       "orbital_period": "549",
#       "population": "unknown",
#       "residents": [],
#       "rotation_period": "23",
#       "surface_water": "100",
#       "terrain": "tundra, ice caves, mountain ranges",
#       "url": "http://swapi.dev/api/planets/4/"
#     },
#     {
#       "climate": "murky",
#       "created": "2014-12-10T11:42:22.590000Z",
#       "diameter": "8900",
#       "edited": "2014-12-20T20:58:18.425000Z",
#       "films": [
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gravity": "N/A",
#       "name": "Dagobah",
#       "orbital_period": "341",
#       "population": "unknown",
#       "residents": [],
#       "rotation_period": "23",
#       "surface_water": "8",
#       "terrain": "swamp, jungles",
#       "url": "http://swapi.dev/api/planets/5/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-10T11:43:55.240000Z",
#       "diameter": "118000",
#       "edited": "2014-12-20T20:58:18.427000Z",
#       "films": [
#         "http://swapi.dev/api/films/2/"
#       ],
#       "gravity": "1.5 (surface), 1 standard (Cloud City)",
#       "name": "Bespin",
#       "orbital_period": "5110",
#       "population": "6000000",
#       "residents": [
#         "http://swapi.dev/api/people/26/"
#       ],
#       "rotation_period": "12",
#       "surface_water": "0",
#       "terrain": "gas giant",
#       "url": "http://swapi.dev/api/planets/6/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-10T11:50:29.349000Z",
#       "diameter": "4900",
#       "edited": "2014-12-20T20:58:18.429000Z",
#       "films": [
#         "http://swapi.dev/api/films/3/"
#       ],
#       "gravity": "0.85 standard",
#       "name": "Endor",
#       "orbital_period": "402",
#       "population": "30000000",
#       "residents": [
#         "http://swapi.dev/api/people/30/"
#       ],
#       "rotation_period": "18",
#       "surface_water": "8",
#       "terrain": "forests, mountains, lakes",
#       "url": "http://swapi.dev/api/planets/7/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-10T11:52:31.066000Z",
#       "diameter": "12120",
#       "edited": "2014-12-20T20:58:18.430000Z",
#       "films": [
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gravity": "1 standard",
#       "name": "Naboo",
#       "orbital_period": "312",
#       "population": "4500000000",
#       "residents": [
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/21/",
#         "http://swapi.dev/api/people/35/",
#         "http://swapi.dev/api/people/36/",
#         "http://swapi.dev/api/people/37/",
#         "http://swapi.dev/api/people/38/",
#         "http://swapi.dev/api/people/39/",
#         "http://swapi.dev/api/people/42/",
#         "http://swapi.dev/api/people/60/",
#         "http://swapi.dev/api/people/61/",
#         "http://swapi.dev/api/people/66/"
#       ],
#       "rotation_period": "26",
#       "surface_water": "12",
#       "terrain": "grassy hills, swamps, forests, mountains",
#       "url": "http://swapi.dev/api/planets/8/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-10T11:54:13.921000Z",
#       "diameter": "12240",
#       "edited": "2014-12-20T20:58:18.432000Z",
#       "films": [
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gravity": "1 standard",
#       "name": "Coruscant",
#       "orbital_period": "368",
#       "population": "1000000000000",
#       "residents": [
#         "http://swapi.dev/api/people/34/",
#         "http://swapi.dev/api/people/55/",
#         "http://swapi.dev/api/people/74/"
#       ],
#       "rotation_period": "24",
#       "surface_water": "unknown",
#       "terrain": "cityscape, mountains",
#       "url": "http://swapi.dev/api/planets/9/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-10T12:45:06.577000Z",
#       "diameter": "19720",
#       "edited": "2014-12-20T20:58:18.434000Z",
#       "films": [
#         "http://swapi.dev/api/films/5/"
#       ],
#       "gravity": "1 standard",
#       "name": "Kamino",
#       "orbital_period": "463",
#       "population": "1000000000",
#       "residents": [
#         "http://swapi.dev/api/people/22/",
#         "http://swapi.dev/api/people/72/",
#         "http://swapi.dev/api/people/73/"
#       ],
#       "rotation_period": "27",
#       "surface_water": "100",
#       "terrain": "ocean",
#       "url": "http://swapi.dev/api/planets/10/"
#     }
#   ]
# }

# %%
#for loop to list names in films
for planets in planets_response["results"]:
    planet_name = planets["name"]
    print(planet_name)
# Out:
# Tatooine
# Alderaan
# Yavin IV
# Hoth
# Dagobah
# Bespin
# Endor
# Naboo
# Coruscant
# Kamino

# %%
planet_name = []
page = ["1", "2", "3", "4", "5", "6"]
url_planets_next = f"http://swapi.dev/api/planets/?page="

for x in page:
    planets_response_next = requests.get(url_planets_next + x).json()
    
#for loop to list all planet names in films
    for planets in planets_response_next["results"]:
        planet_name = planets["name"]
        print(planet_name)
# Out:
# Tatooine
# Alderaan
# Yavin IV
# Hoth
# Dagobah
# Bespin
# Endor
# Naboo
# Coruscant
# Kamino
# Geonosis
# Utapau
# Mustafar
# Kashyyyk
# Polis Massa
# Mygeeto
# Felucia
# Cato Neimoidia
# Saleucami
# Stewjon
# Eriadu
# Corellia
# Rodia
# Nal Hutta
# Dantooine
# Bestine IV
# Ord Mantell
# unknown
# Trandosha
# Socorro
# Mon Cala
# Chandrila
# Sullust
# Toydaria
# Malastare
# Dathomir
# Ryloth
# Aleen Minor
# Vulpter
# Troiken
# Tund
# Haruun Kal
# Cerea
# Glee Anselm
# Iridonia
# Tholoth
# Iktotch
# Quermia
# Dorin
# Champala
# Mirial
# Serenno
# Concord Dawn
# Zolan
# Ojom
# Skako
# Muunilinst
# Shili
# Kalee
# Umbara

# %%
print(json.dumps(planets_response_next, indent=2, sort_keys=True))
# Out:
# {
#   "count": 60,
#   "next": null,
#   "previous": "http://swapi.dev/api/planets/?page=5",
#   "results": [
#     {
#       "climate": "unknown",
#       "created": "2014-12-20T16:44:46.318000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.508000Z",
#       "films": [],
#       "gravity": "unknown",
#       "name": "Mirial",
#       "orbital_period": "unknown",
#       "population": "unknown",
#       "residents": [
#         "http://swapi.dev/api/people/64/",
#         "http://swapi.dev/api/people/65/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "unknown",
#       "terrain": "deserts",
#       "url": "http://swapi.dev/api/planets/51/"
#     },
#     {
#       "climate": "unknown",
#       "created": "2014-12-20T16:52:13.357000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.510000Z",
#       "films": [],
#       "gravity": "unknown",
#       "name": "Serenno",
#       "orbital_period": "unknown",
#       "population": "unknown",
#       "residents": [
#         "http://swapi.dev/api/people/67/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "unknown",
#       "terrain": "rainforests, rivers, mountains",
#       "url": "http://swapi.dev/api/planets/52/"
#     },
#     {
#       "climate": "unknown",
#       "created": "2014-12-20T16:54:39.909000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.512000Z",
#       "films": [],
#       "gravity": "unknown",
#       "name": "Concord Dawn",
#       "orbital_period": "unknown",
#       "population": "unknown",
#       "residents": [
#         "http://swapi.dev/api/people/69/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "unknown",
#       "terrain": "jungles, forests, deserts",
#       "url": "http://swapi.dev/api/planets/53/"
#     },
#     {
#       "climate": "unknown",
#       "created": "2014-12-20T16:56:37.250000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.514000Z",
#       "films": [],
#       "gravity": "unknown",
#       "name": "Zolan",
#       "orbital_period": "unknown",
#       "population": "unknown",
#       "residents": [
#         "http://swapi.dev/api/people/70/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "unknown",
#       "terrain": "unknown",
#       "url": "http://swapi.dev/api/planets/54/"
#     },
#     {
#       "climate": "frigid",
#       "created": "2014-12-20T17:27:41.286000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.516000Z",
#       "films": [],
#       "gravity": "unknown",
#       "name": "Ojom",
#       "orbital_period": "unknown",
#       "population": "500000000",
#       "residents": [
#         "http://swapi.dev/api/people/71/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "100",
#       "terrain": "oceans, glaciers",
#       "url": "http://swapi.dev/api/planets/55/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-20T17:50:47.864000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.517000Z",
#       "films": [],
#       "gravity": "1",
#       "name": "Skako",
#       "orbital_period": "384",
#       "population": "500000000000",
#       "residents": [
#         "http://swapi.dev/api/people/76/"
#       ],
#       "rotation_period": "27",
#       "surface_water": "unknown",
#       "terrain": "urban, vines",
#       "url": "http://swapi.dev/api/planets/56/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-20T17:57:47.420000Z",
#       "diameter": "13800",
#       "edited": "2014-12-20T20:58:18.519000Z",
#       "films": [],
#       "gravity": "1",
#       "name": "Muunilinst",
#       "orbital_period": "412",
#       "population": "5000000000",
#       "residents": [
#         "http://swapi.dev/api/people/77/"
#       ],
#       "rotation_period": "28",
#       "surface_water": "25",
#       "terrain": "plains, forests, hills, mountains",
#       "url": "http://swapi.dev/api/planets/57/"
#     },
#     {
#       "climate": "temperate",
#       "created": "2014-12-20T18:43:14.049000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.521000Z",
#       "films": [],
#       "gravity": "1",
#       "name": "Shili",
#       "orbital_period": "unknown",
#       "population": "unknown",
#       "residents": [
#         "http://swapi.dev/api/people/78/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "unknown",
#       "terrain": "cities, savannahs, seas, plains",
#       "url": "http://swapi.dev/api/planets/58/"
#     },
#     {
#       "climate": "arid, temperate, tropical",
#       "created": "2014-12-20T19:43:51.278000Z",
#       "diameter": "13850",
#       "edited": "2014-12-20T20:58:18.523000Z",
#       "films": [],
#       "gravity": "1",
#       "name": "Kalee",
#       "orbital_period": "378",
#       "population": "4000000000",
#       "residents": [
#         "http://swapi.dev/api/people/79/"
#       ],
#       "rotation_period": "23",
#       "surface_water": "unknown",
#       "terrain": "rainforests, cliffs, canyons, seas",
#       "url": "http://swapi.dev/api/planets/59/"
#     },
#     {
#       "climate": "unknown",
#       "created": "2014-12-20T20:18:36.256000Z",
#       "diameter": "unknown",
#       "edited": "2014-12-20T20:58:18.525000Z",
#       "films": [],
#       "gravity": "unknown",
#       "name": "Umbara",
#       "orbital_period": "unknown",
#       "population": "unknown",
#       "residents": [
#         "http://swapi.dev/api/people/82/"
#       ],
#       "rotation_period": "unknown",
#       "surface_water": "unknown",
#       "terrain": "unknown",
#       "url": "http://swapi.dev/api/planets/60/"
#     }
#   ]
# }

# %%
#planets pprint (results)
print(json.dumps(planets_response["results"], indent=2, sort_keys=True))
# Out:
# [
#   {
#     "climate": "arid",
#     "created": "2014-12-09T13:50:49.641000Z",
#     "diameter": "10465",
#     "edited": "2014-12-20T20:58:18.411000Z",
#     "films": [
#       "http://swapi.dev/api/films/1/",
#       "http://swapi.dev/api/films/3/",
#       "http://swapi.dev/api/films/4/",
#       "http://swapi.dev/api/films/5/",
#       "http://swapi.dev/api/films/6/"
#     ],
#     "gravity": "1 standard",
#     "name": "Tatooine",
#     "orbital_period": "304",
#     "population": "200000",
#     "residents": [
#       "http://swapi.dev/api/people/1/",
#       "http://swapi.dev/api/people/2/",
#       "http://swapi.dev/api/people/4/",
#       "http://swapi.dev/api/people/6/",
#       "http://swapi.dev/api/people/7/",
#       "http://swapi.dev/api/people/8/",
#       "http://swapi.dev/api/people/9/",
#       "http://swapi.dev/api/people/11/",
#       "http://swapi.dev/api/people/43/",
#       "http://swapi.dev/api/people/62/"
#     ],
#     "rotation_period": "23",
#     "surface_water": "1",
#     "terrain": "desert",
#     "url": "http://swapi.dev/api/planets/1/"
#   },
#   {
#     "climate": "temperate",
#     "created": "2014-12-10T11:35:48.479000Z",
#     "diameter": "12500",
#     "edited": "2014-12-20T20:58:18.420000Z",
#     "films": [
#       "http://swapi.dev/api/films/1/",
#       "http://swapi.dev/api/films/6/"
#     ],
#     "gravity": "1 standard",
#     "name": "Alderaan",
#     "orbital_period": "364",
#     "population": "2000000000",
#     "residents": [
#       "http://swapi.dev/api/people/5/",
#       "http://swapi.dev/api/people/68/",
#       "http://swapi.dev/api/people/81/"
#     ],
#     "rotation_period": "24",
#     "surface_water": "40",
#     "terrain": "grasslands, mountains",
#     "url": "http://swapi.dev/api/planets/2/"
#   },
#   {
#     "climate": "temperate, tropical",
#     "created": "2014-12-10T11:37:19.144000Z",
#     "diameter": "10200",
#     "edited": "2014-12-20T20:58:18.421000Z",
#     "films": [
#       "http://swapi.dev/api/films/1/"
#     ],
#     "gravity": "1 standard",
#     "name": "Yavin IV",
#     "orbital_period": "4818",
#     "population": "1000",
#     "residents": [],
#     "rotation_period": "24",
#     "surface_water": "8",
#     "terrain": "jungle, rainforests",
#     "url": "http://swapi.dev/api/planets/3/"
#   },
#   {
#     "climate": "frozen",
#     "created": "2014-12-10T11:39:13.934000Z",
#     "diameter": "7200",
#     "edited": "2014-12-20T20:58:18.423000Z",
#     "films": [
#       "http://swapi.dev/api/films/2/"
#     ],
#     "gravity": "1.1 standard",
#     "name": "Hoth",
#     "orbital_period": "549",
#     "population": "unknown",
#     "residents": [],
#     "rotation_period": "23",
#     "surface_water": "100",
#     "terrain": "tundra, ice caves, mountain ranges",
#     "url": "http://swapi.dev/api/planets/4/"
#   },
#   {
#     "climate": "murky",
#     "created": "2014-12-10T11:42:22.590000Z",
#     "diameter": "8900",
#     "edited": "2014-12-20T20:58:18.425000Z",
#     "films": [
#       "http://swapi.dev/api/films/2/",
#       "http://swapi.dev/api/films/3/",
#       "http://swapi.dev/api/films/6/"
#     ],
#     "gravity": "N/A",
#     "name": "Dagobah",
#     "orbital_period": "341",
#     "population": "unknown",
#     "residents": [],
#     "rotation_period": "23",
#     "surface_water": "8",
#     "terrain": "swamp, jungles",
#     "url": "http://swapi.dev/api/planets/5/"
#   },
#   {
#     "climate": "temperate",
#     "created": "2014-12-10T11:43:55.240000Z",
#     "diameter": "118000",
#     "edited": "2014-12-20T20:58:18.427000Z",
#     "films": [
#       "http://swapi.dev/api/films/2/"
#     ],
#     "gravity": "1.5 (surface), 1 standard (Cloud City)",
#     "name": "Bespin",
#     "orbital_period": "5110",
#     "population": "6000000",
#     "residents": [
#       "http://swapi.dev/api/people/26/"
#     ],
#     "rotation_period": "12",
#     "surface_water": "0",
#     "terrain": "gas giant",
#     "url": "http://swapi.dev/api/planets/6/"
#   },
#   {
#     "climate": "temperate",
#     "created": "2014-12-10T11:50:29.349000Z",
#     "diameter": "4900",
#     "edited": "2014-12-20T20:58:18.429000Z",
#     "films": [
#       "http://swapi.dev/api/films/3/"
#     ],
#     "gravity": "0.85 standard",
#     "name": "Endor",
#     "orbital_period": "402",
#     "population": "30000000",
#     "residents": [
#       "http://swapi.dev/api/people/30/"
#     ],
#     "rotation_period": "18",
#     "surface_water": "8",
#     "terrain": "forests, mountains, lakes",
#     "url": "http://swapi.dev/api/planets/7/"
#   },
#   {
#     "climate": "temperate",
#     "created": "2014-12-10T11:52:31.066000Z",
#     "diameter": "12120",
#     "edited": "2014-12-20T20:58:18.430000Z",
#     "films": [
#       "http://swapi.dev/api/films/3/",
#       "http://swapi.dev/api/films/4/",
#       "http://swapi.dev/api/films/5/",
#       "http://swapi.dev/api/films/6/"
#     ],
#     "gravity": "1 standard",
#     "name": "Naboo",
#     "orbital_period": "312",
#     "population": "4500000000",
#     "residents": [
#       "http://swapi.dev/api/people/3/",
#       "http://swapi.dev/api/people/21/",
#       "http://swapi.dev/api/people/35/",
#       "http://swapi.dev/api/people/36/",
#       "http://swapi.dev/api/people/37/",
#       "http://swapi.dev/api/people/38/",
#       "http://swapi.dev/api/people/39/",
#       "http://swapi.dev/api/people/42/",
#       "http://swapi.dev/api/people/60/",
#       "http://swapi.dev/api/people/61/",
#       "http://swapi.dev/api/people/66/"
#     ],
#     "rotation_period": "26",
#     "surface_water": "12",
#     "terrain": "grassy hills, swamps, forests, mountains",
#     "url": "http://swapi.dev/api/planets/8/"
#   },
#   {
#     "climate": "temperate",
#     "created": "2014-12-10T11:54:13.921000Z",
#     "diameter": "12240",
#     "edited": "2014-12-20T20:58:18.432000Z",
#     "films": [
#       "http://swapi.dev/api/films/3/",
#       "http://swapi.dev/api/films/4/",
#       "http://swapi.dev/api/films/5/",
#       "http://swapi.dev/api/films/6/"
#     ],
#     "gravity": "1 standard",
#     "name": "Coruscant",
#     "orbital_period": "368",
#     "population": "1000000000000",
#     "residents": [
#       "http://swapi.dev/api/people/34/",
#       "http://swapi.dev/api/people/55/",
#       "http://swapi.dev/api/people/74/"
#     ],
#     "rotation_period": "24",
#     "surface_water": "unknown",
#     "terrain": "cityscape, mountains",
#     "url": "http://swapi.dev/api/planets/9/"
#   },
#   {
#     "climate": "temperate",
#     "created": "2014-12-10T12:45:06.577000Z",
#     "diameter": "19720",
#     "edited": "2014-12-20T20:58:18.434000Z",
#     "films": [
#       "http://swapi.dev/api/films/5/"
#     ],
#     "gravity": "1 standard",
#     "name": "Kamino",
#     "orbital_period": "463",
#     "population": "1000000000",
#     "residents": [
#       "http://swapi.dev/api/people/22/",
#       "http://swapi.dev/api/people/72/",
#       "http://swapi.dev/api/people/73/"
#     ],
#     "rotation_period": "27",
#     "surface_water": "100",
#     "terrain": "ocean",
#     "url": "http://swapi.dev/api/planets/10/"
#   }
# ]

# %%
#count number of planets
planet_count = planets_response["count"]
print(f'The number of Star Wars planets in this API is {planet_count}')
# Out:
# The number of Star Wars planets in this API is 60

# %%
#species pprint
print(json.dumps(species_response, indent=2, sort_keys=True))
# Out:
# {
#   "count": 37,
#   "next": "http://swapi.dev/api/species/?page=2",
#   "previous": null,
#   "results": [
#     {
#       "average_height": "180",
#       "average_lifespan": "120",
#       "classification": "mammal",
#       "created": "2014-12-10T13:52:11.567000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.136000Z",
#       "eye_colors": "brown, blue, green, hazel, grey, amber",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "hair_colors": "blonde, brown, black, red",
#       "homeworld": "http://swapi.dev/api/planets/9/",
#       "language": "Galactic Basic",
#       "name": "Human",
#       "people": [
#         "http://swapi.dev/api/people/66/",
#         "http://swapi.dev/api/people/67/",
#         "http://swapi.dev/api/people/68/",
#         "http://swapi.dev/api/people/74/"
#       ],
#       "skin_colors": "caucasian, black, asian, hispanic",
#       "url": "http://swapi.dev/api/species/1/"
#     },
#     {
#       "average_height": "n/a",
#       "average_lifespan": "indefinite",
#       "classification": "artificial",
#       "created": "2014-12-10T15:16:16.259000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.139000Z",
#       "eye_colors": "n/a",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "hair_colors": "n/a",
#       "homeworld": null,
#       "language": "n/a",
#       "name": "Droid",
#       "people": [
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/8/",
#         "http://swapi.dev/api/people/23/"
#       ],
#       "skin_colors": "n/a",
#       "url": "http://swapi.dev/api/species/2/"
#     },
#     {
#       "average_height": "210",
#       "average_lifespan": "400",
#       "classification": "mammal",
#       "created": "2014-12-10T16:44:31.486000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.142000Z",
#       "eye_colors": "blue, green, yellow, brown, golden, red",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "hair_colors": "black, brown",
#       "homeworld": "http://swapi.dev/api/planets/14/",
#       "language": "Shyriiwook",
#       "name": "Wookie",
#       "people": [
#         "http://swapi.dev/api/people/13/",
#         "http://swapi.dev/api/people/80/"
#       ],
#       "skin_colors": "gray",
#       "url": "http://swapi.dev/api/species/3/"
#     },
#     {
#       "average_height": "170",
#       "average_lifespan": "unknown",
#       "classification": "sentient",
#       "created": "2014-12-10T17:05:26.471000Z",
#       "designation": "reptilian",
#       "edited": "2014-12-20T21:36:42.144000Z",
#       "eye_colors": "black",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "hair_colors": "n/a",
#       "homeworld": "http://swapi.dev/api/planets/23/",
#       "language": "Galatic Basic",
#       "name": "Rodian",
#       "people": [
#         "http://swapi.dev/api/people/15/"
#       ],
#       "skin_colors": "green, blue",
#       "url": "http://swapi.dev/api/species/4/"
#     },
#     {
#       "average_height": "300",
#       "average_lifespan": "1000",
#       "classification": "gastropod",
#       "created": "2014-12-10T17:12:50.410000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.146000Z",
#       "eye_colors": "yellow, red",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hair_colors": "n/a",
#       "homeworld": "http://swapi.dev/api/planets/24/",
#       "language": "Huttese",
#       "name": "Hutt",
#       "people": [
#         "http://swapi.dev/api/people/16/"
#       ],
#       "skin_colors": "green, brown, tan",
#       "url": "http://swapi.dev/api/species/5/"
#     },
#     {
#       "average_height": "66",
#       "average_lifespan": "900",
#       "classification": "mammal",
#       "created": "2014-12-15T12:27:22.877000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.148000Z",
#       "eye_colors": "brown, green, yellow",
#       "films": [
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "hair_colors": "brown, white",
#       "homeworld": "http://swapi.dev/api/planets/28/",
#       "language": "Galactic basic",
#       "name": "Yoda's species",
#       "people": [
#         "http://swapi.dev/api/people/20/"
#       ],
#       "skin_colors": "green, yellow",
#       "url": "http://swapi.dev/api/species/6/"
#     },
#     {
#       "average_height": "200",
#       "average_lifespan": "unknown",
#       "classification": "reptile",
#       "created": "2014-12-15T13:07:47.704000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.151000Z",
#       "eye_colors": "yellow, orange",
#       "films": [
#         "http://swapi.dev/api/films/2/"
#       ],
#       "hair_colors": "none",
#       "homeworld": "http://swapi.dev/api/planets/29/",
#       "language": "Dosh",
#       "name": "Trandoshan",
#       "people": [
#         "http://swapi.dev/api/people/24/"
#       ],
#       "skin_colors": "brown, green",
#       "url": "http://swapi.dev/api/species/7/"
#     },
#     {
#       "average_height": "160",
#       "average_lifespan": "unknown",
#       "classification": "amphibian",
#       "created": "2014-12-18T11:09:52.263000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.153000Z",
#       "eye_colors": "yellow",
#       "films": [
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hair_colors": "none",
#       "homeworld": "http://swapi.dev/api/planets/31/",
#       "language": "Mon Calamarian",
#       "name": "Mon Calamari",
#       "people": [
#         "http://swapi.dev/api/people/27/"
#       ],
#       "skin_colors": "red, blue, brown, magenta",
#       "url": "http://swapi.dev/api/species/8/"
#     },
#     {
#       "average_height": "100",
#       "average_lifespan": "unknown",
#       "classification": "mammal",
#       "created": "2014-12-18T11:22:00.285000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.155000Z",
#       "eye_colors": "orange, brown",
#       "films": [
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hair_colors": "white, brown, black",
#       "homeworld": "http://swapi.dev/api/planets/7/",
#       "language": "Ewokese",
#       "name": "Ewok",
#       "people": [
#         "http://swapi.dev/api/people/30/"
#       ],
#       "skin_colors": "brown",
#       "url": "http://swapi.dev/api/species/9/"
#     },
#     {
#       "average_height": "180",
#       "average_lifespan": "unknown",
#       "classification": "mammal",
#       "created": "2014-12-18T11:26:20.103000Z",
#       "designation": "sentient",
#       "edited": "2014-12-20T21:36:42.157000Z",
#       "eye_colors": "black",
#       "films": [
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hair_colors": "none",
#       "homeworld": "http://swapi.dev/api/planets/33/",
#       "language": "Sullutese",
#       "name": "Sullustan",
#       "people": [
#         "http://swapi.dev/api/people/31/"
#       ],
#       "skin_colors": "pale",
#       "url": "http://swapi.dev/api/species/10/"
#     }
#   ]
# }

# %%
#number of species
species_count = species_response["count"]
print(f'The number of Star Wars species in this API is {species_count}')
# Out:
# The number of Star Wars species in this API is 37

# %%
species_types = []
page = ["1", "2", "3", "4"]
find_species_url = f"http://swapi.dev/api/species/?page="

for x in page:
    find_species_response = requests.get(find_species_url + x).json()
    
#for loop to list names in films
    for species in find_species_response["results"]:
        species_name = species["name"]
        species_types.append(species_name)
        print(f'{species_name} found!')
# Out:
# Human found!
# Droid found!
# Wookie found!
# Rodian found!
# Hutt found!
# Yoda's species found!
# Trandoshan found!
# Mon Calamari found!
# Ewok found!
# Sullustan found!
# Neimodian found!
# Gungan found!
# Toydarian found!
# Dug found!
# Twi'lek found!
# Aleena found!
# Vulptereen found!
# Xexto found!
# Toong found!
# Cerean found!
# Nautolan found!
# Zabrak found!
# Tholothian found!
# Iktotchi found!
# Quermian found!
# Kel Dor found!
# Chagrian found!
# Geonosian found!
# Mirialan found!
# Clawdite found!
# Besalisk found!
# Kaminoan found!
# Skakoan found!
# Muun found!
# Togruta found!
# Kaleesh found!
# Pau'an found!

# %%
## Set url for API
url_people = 'https://swapi.dev/api/people/?search='

# List of characters
'''
search_characters = ['R2-D2', 'C-3PO', 'Darth Vader', 'Leia', 'Luke Skywalker', 'Chewbacca', 'Dooku', \
                     'Anakin Skywalker', 'Obi-Wan Kenobi', 'Lando Calrissian', 'Han Solo', 'Yoda',\
                     'Mace Windu', 'Plo Koon', 'Jango Fett', 'Grievous', 'Palpatine', 'Darth Maul',\
                     'Qui-Gon Jinn', 'Padmé', 'Jar Jar Binks', 'Han Solo', 'Nute Gunray', 'Ki-Adi-Mundi', 'Kit Fisto']
'''
search_characters = character_list

# Set empty lists to hold character's height and mass
height = []
mass = []
starwars_characters = []

# Loop through each character and make API request
for character in search_characters:
    
    # Create search query, make request and store in json
    query = url_people + character
    response = requests.get(query)
    response_json = response.json()
    
    
    # Try to grab the height and mass of characters if they are available in the Star Wars API
    try:
        height.append(response_json['results'][0]['height'])
        mass.append(response_json['results'][0]['mass'])
        starwars_characters.append(character)
        print(f"{character} found! Appending stats")
        
   
    # Handle exceptions for a character that is not available in the Star Wars API
    except: 
        print(f"{character} not found")
        pass
# Out:
# Luke Skywalker found! Appending stats
# C-3PO found! Appending stats
# R2-D2 found! Appending stats
# Darth Vader found! Appending stats
# Leia Organa found! Appending stats
# Owen Lars found! Appending stats
# Beru Whitesun lars found! Appending stats
# R5-D4 found! Appending stats
# Biggs Darklighter found! Appending stats
# Obi-Wan Kenobi found! Appending stats
# Anakin Skywalker found! Appending stats
# Wilhuff Tarkin found! Appending stats
# Chewbacca found! Appending stats
# Han Solo found! Appending stats
# Greedo found! Appending stats
# Jabba Desilijic Tiure found! Appending stats
# Wedge Antilles found! Appending stats
# Jek Tono Porkins found! Appending stats
# Yoda found! Appending stats
# Palpatine found! Appending stats
# Boba Fett found! Appending stats
# IG-88 found! Appending stats
# Bossk found! Appending stats
# Lando Calrissian found! Appending stats
# Lobot found! Appending stats
# Ackbar found! Appending stats
# Mon Mothma found! Appending stats
# Arvel Crynyd found! Appending stats
# Wicket Systri Warrick found! Appending stats
# Nien Nunb found! Appending stats
# Qui-Gon Jinn found! Appending stats
# Nute Gunray found! Appending stats
# Finis Valorum found! Appending stats
# Padmé Amidala found! Appending stats
# Jar Jar Binks found! Appending stats
# Roos Tarpals found! Appending stats
# Rugor Nass found! Appending stats
# Ric Olié found! Appending stats
# Watto found! Appending stats
# Sebulba found! Appending stats
# Quarsh Panaka found! Appending stats
# Shmi Skywalker found! Appending stats
# Darth Maul found! Appending stats
# Bib Fortuna found! Appending stats
# Ayla Secura found! Appending stats
# Ratts Tyerel found! Appending stats
# Dud Bolt found! Appending stats
# Gasgano found! Appending stats
# Ben Quadinaros found! Appending stats
# Mace Windu found! Appending stats
# Ki-Adi-Mundi found! Appending stats
# Kit Fisto found! Appending stats
# Eeth Koth found! Appending stats
# Adi Gallia found! Appending stats
# Saesee Tiin found! Appending stats
# Yarael Poof found! Appending stats
# Plo Koon found! Appending stats
# Mas Amedda found! Appending stats
# Gregar Typho found! Appending stats
# Cordé found! Appending stats
# Cliegg Lars found! Appending stats
# Poggle the Lesser found! Appending stats
# Luminara Unduli found! Appending stats
# Barriss Offee found! Appending stats
# Dormé found! Appending stats
# Dooku found! Appending stats
# Bail Prestor Organa found! Appending stats
# Jango Fett found! Appending stats
# Zam Wesell found! Appending stats
# Dexter Jettster found! Appending stats
# Lama Su found! Appending stats
# Taun We found! Appending stats
# Jocasta Nu found! Appending stats
# R4-P17 found! Appending stats
# Wat Tambor found! Appending stats
# San Hill found! Appending stats
# Shaak Ti found! Appending stats
# Grievous found! Appending stats
# Tarfful found! Appending stats
# Raymus Antilles found! Appending stats
# Sly Moore found! Appending stats
# Tion Medon found! Appending stats

# %%
# count characters in list
char_count = len(search_characters)
print(f'The number of characters found is {char_count}')
# Out:
# The number of characters found is 82

# %%
#create new dataframe for all characters found
characters_df = pd.DataFrame({"Character": search_characters,
                              "Height": height,
                              "Mass": mass})
print(characters_df)
# Out:
#           Character Height Mass
# 0    Luke Skywalker    172   77
# 1             C-3PO    167   75
# 2             R2-D2     96   32
# 3       Darth Vader    202  136
# 4       Leia Organa    150   49
# ..              ...    ...  ...
# 77         Grievous    216  159
# 78          Tarfful    234  136
# 79  Raymus Antilles    188   79
# 80        Sly Moore    178   48
# 81       Tion Medon    206   80
#
# [82 rows x 3 columns]

# %%
#drop characters that don't have a height or mass listed and create new dataframe for tracking purposes
clean_characters_df = characters_df.drop(characters_df[characters_df['Height'] == 'unknown'].index) 
clean_characters_df = characters_df.drop(characters_df[characters_df['Mass'] == 'unknown'].index) 

print(clean_characters_df)
# Out:
#                 Character Height   Mass
# 0          Luke Skywalker    172     77
# 1                   C-3PO    167     75
# 2                   R2-D2     96     32
# 3             Darth Vader    202    136
# 4             Leia Organa    150     49
# 5               Owen Lars    178    120
# 6      Beru Whitesun lars    165     75
# 7                   R5-D4     97     32
# 8       Biggs Darklighter    183     84
# 9          Obi-Wan Kenobi    182     77
# 10       Anakin Skywalker    188     84
# 12              Chewbacca    228    112
# 13               Han Solo    180     80
# 14                 Greedo    173     74
# 15  Jabba Desilijic Tiure    175  1,358
# 16         Wedge Antilles    170     77
# 17       Jek Tono Porkins    180    110
# 18                   Yoda     66     17
# 19              Palpatine    170     75
# 20              Boba Fett    183   78.2
# 21                  IG-88    200    140
# 22                  Bossk    190    113
# 23       Lando Calrissian    177     79
# 24                  Lobot    175     79
# 25                 Ackbar    180     83
# 28  Wicket Systri Warrick     88     20
# 29              Nien Nunb    160     68
# 30           Qui-Gon Jinn    193     89
# 31            Nute Gunray    191     90
# 33          Padmé Amidala    185     45
# 34          Jar Jar Binks    196     66
# 35           Roos Tarpals    224     82
# 39                Sebulba    112     40
# 42             Darth Maul    175     80
# 44            Ayla Secura    178     55
# 45           Ratts Tyerel     79     15
# 46               Dud Bolt     94     45
# 48         Ben Quadinaros    163     65
# 49             Mace Windu    188     84
# 50           Ki-Adi-Mundi    198     82
# 51              Kit Fisto    196     87
# 53             Adi Gallia    184     50
# 56               Plo Koon    188     80
# 58           Gregar Typho    185     85
# 61      Poggle the Lesser    183     80
# 62        Luminara Unduli    170   56.2
# 63          Barriss Offee    166     50
# 65                  Dooku    193     80
# 67             Jango Fett    183     79
# 68             Zam Wesell    168     55
# 69        Dexter Jettster    198    102
# 70                Lama Su    229     88
# 74             Wat Tambor    193     48
# 76               Shaak Ti    178     57
# 77               Grievous    216    159
# 78                Tarfful    234    136
# 79        Raymus Antilles    188     79
# 80              Sly Moore    178     48
# 81             Tion Medon    206     80

# %%
#reset index to new character count after dropping unknowns
clean_characters_df = clean_characters_df.reset_index(drop=True)
clean_characters_df.iloc[[14],[2]]=1358
clean_characters_df.iloc[[14],[0]]="Jabba The Hutt"
clean_characters_df
# Out:
#                 Character Height  Mass
# 0          Luke Skywalker    172    77
# 1                   C-3PO    167    75
# 2                   R2-D2     96    32
# 3             Darth Vader    202   136
# 4             Leia Organa    150    49
# 5               Owen Lars    178   120
# 6      Beru Whitesun lars    165    75
# 7                   R5-D4     97    32
# 8       Biggs Darklighter    183    84
# 9          Obi-Wan Kenobi    182    77
# 10       Anakin Skywalker    188    84
# 11              Chewbacca    228   112
# 12               Han Solo    180    80
# 13                 Greedo    173    74
# 14         Jabba The Hutt    175  1358
# 15         Wedge Antilles    170    77
# 16       Jek Tono Porkins    180   110
# 17                   Yoda     66    17
# 18              Palpatine    170    75
# 19              Boba Fett    183  78.2
# 20                  IG-88    200   140
# 21                  Bossk    190   113
# 22       Lando Calrissian    177    79
# 23                  Lobot    175    79
# 24                 Ackbar    180    83
# 25  Wicket Systri Warrick     88    20
# 26              Nien Nunb    160    68
# 27           Qui-Gon Jinn    193    89
# 28            Nute Gunray    191    90
# 29          Padmé Amidala    185    45
# 30          Jar Jar Binks    196    66
# 31           Roos Tarpals    224    82
# 32                Sebulba    112    40
# 33             Darth Maul    175    80
# 34            Ayla Secura    178    55
# 35           Ratts Tyerel     79    15
# 36               Dud Bolt     94    45
# 37         Ben Quadinaros    163    65
# 38             Mace Windu    188    84
# 39           Ki-Adi-Mundi    198    82
# 40              Kit Fisto    196    87
# 41             Adi Gallia    184    50
# 42               Plo Koon    188    80
# 43           Gregar Typho    185    85
# 44      Poggle the Lesser    183    80
# 45        Luminara Unduli    170  56.2
# 46          Barriss Offee    166    50
# 47                  Dooku    193    80
# 48             Jango Fett    183    79
# 49             Zam Wesell    168    55
# 50        Dexter Jettster    198   102
# 51                Lama Su    229    88
# 52             Wat Tambor    193    48
# 53               Shaak Ti    178    57
# 54               Grievous    216   159
# 55                Tarfful    234   136
# 56        Raymus Antilles    188    79
# 57              Sly Moore    178    48
# 58             Tion Medon    206    80

# %%
#lists for height and mass
for i in range(0, len(clean_characters_df["Height"])):
    clean_characters_df["Height"][i] = float(clean_characters_df["Height"][i])
print(clean_characters_df["Height"])

for i in range(0, len(clean_characters_df["Mass"])):
    clean_characters_df["Mass"][i] = round(float(clean_characters_df["Mass"][i]),2)
print(clean_characters_df["Mass"])
# Out:
# 0     172
# 1     167
# 2      96
# 3     202
# 4     150
# 5     178
# 6     165
# 7      97
# 8     183
# 9     182
# 10    188
# 11    228
# 12    180
# 13    173
# 14    175
# 15    170
# 16    180
# 17     66
# 18    170
# 19    183
# 20    200
# 21    190
# 22    177
# 23    175
# 24    180
# 25     88
# 26    160
# 27    193
# 28    191
# 29    185
# 30    196
# 31    224
# 32    112
# 33    175
# 34    178
# 35     79
# 36     94
# 37    163
# 38    188
# 39    198
# 40    196
# 41    184
# 42    188
# 43    185
# 44    183
# 45    170
# 46    166
# 47    193
# 48    183
# 49    168
# 50    198
# 51    229
# 52    193
# 53    178
# 54    216
# 55    234
# 56    188
# 57    178
# 58    206
# Name: Height, dtype: object
# 0       77
# 1       75
# 2       32
# 3      136
# 4       49
# 5      120
# 6       75
# 7       32
# 8       84
# 9       77
# 10      84
# 11     112
# 12      80
# 13      74
# 14    1358
# 15      77
# 16     110
# 17      17
# 18      75
# 19    78.2
# 20     140
# 21     113
# 22      79
# 23      79
# 24      83
# 25      20
# 26      68
# 27      89
# 28      90
# 29      45
# 30      66
# 31      82
# 32      40
# 33      80
# 34      55
# 35      15
# 36      45
# 37      65
# 38      84
# 39      82
# 40      87
# 41      50
# 42      80
# 43      85
# 44      80
# 45    56.2
# 46      50
# 47      80
# 48      79
# 49      55
# 50     102
# 51      88
# 52      48
# 53      57
# 54     159
# 55     136
# 56      79
# 57      48
# 58      80
# Name: Mass, dtype: object

# %%
# Height and Mass Dataframes by ascending order
#height
height_df = clean_characters_df.sort_values("Height", ascending=True)
print(height_df)
#mass 
mass_df = clean_characters_df.sort_values("Mass", ascending=True)
print(mass_df)
# Out:
#                 Character Height  Mass
# 17                   Yoda     66    17
# 35           Ratts Tyerel     79    15
# 25  Wicket Systri Warrick     88    20
# 36               Dud Bolt     94    45
# 2                   R2-D2     96    32
# 7                   R5-D4     97    32
# 32                Sebulba    112    40
# 4             Leia Organa    150    49
# 26              Nien Nunb    160    68
# 37         Ben Quadinaros    163    65
# 6      Beru Whitesun lars    165    75
# 46          Barriss Offee    166    50
# 1                   C-3PO    167    75
# 49             Zam Wesell    168    55
# 45        Luminara Unduli    170  56.2
# 18              Palpatine    170    75
# 15         Wedge Antilles    170    77
# 0          Luke Skywalker    172    77
# 13                 Greedo    173    74
# 14         Jabba The Hutt    175  1358
# 33             Darth Maul    175    80
# 23                  Lobot    175    79
# 22       Lando Calrissian    177    79
# 34            Ayla Secura    178    55
# 53               Shaak Ti    178    57
# 5               Owen Lars    178   120
# 57              Sly Moore    178    48
# 16       Jek Tono Porkins    180   110
# 24                 Ackbar    180    83
# 12               Han Solo    180    80
# 9          Obi-Wan Kenobi    182    77
# 48             Jango Fett    183    79
# 19              Boba Fett    183  78.2
# 44      Poggle the Lesser    183    80
# 8       Biggs Darklighter    183    84
# 41             Adi Gallia    184    50
# 43           Gregar Typho    185    85
# 29          Padmé Amidala    185    45
# 38             Mace Windu    188    84
# 42               Plo Koon    188    80
# 56        Raymus Antilles    188    79
# 10       Anakin Skywalker    188    84
# 21                  Bossk    190   113
# 28            Nute Gunray    191    90
# 27           Qui-Gon Jinn    193    89
# 47                  Dooku    193    80
# 52             Wat Tambor    193    48
# 40              Kit Fisto    196    87
# 30          Jar Jar Binks    196    66
# 39           Ki-Adi-Mundi    198    82
# 50        Dexter Jettster    198   102
# 20                  IG-88    200   140
# 3             Darth Vader    202   136
# 58             Tion Medon    206    80
# 54               Grievous    216   159
# 31           Roos Tarpals    224    82
# 11              Chewbacca    228   112
# 51                Lama Su    229    88
# 55                Tarfful    234   136
#                 Character Height  Mass
# 35           Ratts Tyerel     79    15
# 17                   Yoda     66    17
# 25  Wicket Systri Warrick     88    20
# 2                   R2-D2     96    32
# 7                   R5-D4     97    32
# 32                Sebulba    112    40
# 36               Dud Bolt     94    45
# 29          Padmé Amidala    185    45
# 52             Wat Tambor    193    48
# 57              Sly Moore    178    48
# 4             Leia Organa    150    49
# 46          Barriss Offee    166    50
# 41             Adi Gallia    184    50
# 49             Zam Wesell    168    55
# 34            Ayla Secura    178    55
# 45        Luminara Unduli    170  56.2
# 53               Shaak Ti    178    57
# 37         Ben Quadinaros    163    65
# 30          Jar Jar Binks    196    66
# 26              Nien Nunb    160    68
# 13                 Greedo    173    74
# 18              Palpatine    170    75
# 1                   C-3PO    167    75
# 6      Beru Whitesun lars    165    75
# 0          Luke Skywalker    172    77
# 9          Obi-Wan Kenobi    182    77
# 15         Wedge Antilles    170    77
# 19              Boba Fett    183  78.2
# 23                  Lobot    175    79
# 22       Lando Calrissian    177    79
# 56        Raymus Antilles    188    79
# 48             Jango Fett    183    79
# 47                  Dooku    193    80
# 44      Poggle the Lesser    183    80
# 42               Plo Koon    188    80
# 12               Han Solo    180    80
# 58             Tion Medon    206    80
# 33             Darth Maul    175    80
# 39           Ki-Adi-Mundi    198    82
# 31           Roos Tarpals    224    82
# 24                 Ackbar    180    83
# 38             Mace Windu    188    84
# 10       Anakin Skywalker    188    84
# 8       Biggs Darklighter    183    84
# 43           Gregar Typho    185    85
# 40              Kit Fisto    196    87
# 51                Lama Su    229    88
# 27           Qui-Gon Jinn    193    89
# 28            Nute Gunray    191    90
# 50        Dexter Jettster    198   102
# 16       Jek Tono Porkins    180   110
# 11              Chewbacca    228   112
# 21                  Bossk    190   113
# 5               Owen Lars    178   120
# 3             Darth Vader    202   136
# 55                Tarfful    234   136
# 20                  IG-88    200   140
# 54               Grievous    216   159
# 14         Jabba The Hutt    175  1358

# %%
tick_locations = [value for value in clean_characters_df["Character"]]
labels = clean_characters_df["Character"]
plt.figure(figsize=(20, 10))
plt.bar(height_df["Character"], height_df["Height"])
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars (Relative) Character Heights")
# Out:
# Text(0.5, 1.0, 'Star Wars (Relative) Character Heights')

# %%
plt.hist(clean_characters_df["Height"])
plt.title("Star Wars Character Height Distribution")
plt.xlabel("Character Height (arbitratry units)")
plt.ylabel("Counts")
print(sts.normaltest(clean_characters_df["Height"].sample(21)))
sd_numpy = np.std(clean_characters_df["Height"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
var_numpy = np.var(clean_characters_df["Height"],ddof = 0)
print(f"The population variance using the NumPy module is {var_numpy}")
# Calculate the 68-95-99.7 rule using the standard deviation
mean_numpy = np.mean(clean_characters_df["Height"])
print(f"The mean height of Star Wars characters is {mean_numpy}")
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,3)} and {round(mean_numpy+sd_numpy,3)}")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,3)} and {round(mean_numpy+2*sd_numpy,3)}")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,3)} and {round(mean_numpy+3*sd_numpy,3)}")
# Out:
# NormaltestResult(statistic=16.817990389137695, pvalue=0.00022285366903324107)
# The population standard deviation using the NumPy module is 35.23421041336148
# The population variance using the NumPy module is 1241.4495834530308
# The mean height of Star Wars characters is 174.35593220338984
# Roughly 68% of the data is between 139.122 and 209.59
# Roughly 95% of the data is between 103.888 and 244.824
# Roughly 99.7% of the data is between 68.653 and 280.059

# %%
tick_locations = [value for value in clean_characters_df["Character"]]
labels = clean_characters_df["Character"]
plt.figure(figsize=(20, 10))
plt.bar(mass_df["Character"], mass_df["Mass"])
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars (Relative) Character Masses")
# Out:
# Text(0.5, 1.0, 'Star Wars (Relative) Character Masses')

# %%
no_jabba_mass_df = clean_characters_df.drop([14])
no_jabba_mass_df = no_jabba_mass_df.sort_values(["Mass"], ascending=True)
no_jabba_mass_df = no_jabba_mass_df.reset_index(drop=True)

# %%
tick_locations = [value for value in no_jabba_mass_df["Character"]]
labels = no_jabba_mass_df["Character"]
plt.figure(figsize=(20, 10))
plt.bar(no_jabba_mass_df["Character"], no_jabba_mass_df["Mass"])
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars (Relative) Character Masses (No Jabba)")
# Out:
# Text(0.5, 1.0, 'Star Wars (Relative) Character Masses (No Jabba)')

# %%
#scatter plot height vs mass, ## how do I add character labels?? 
x_values = clean_characters_df["Height"]
y_values = clean_characters_df["Mass"]
plt.scatter(x_values, y_values)
plt.grid()
plt.title("Character Height vs Mass")
plt.xlabel("Character Height")
plt.ylabel("Character Mass")
# Out:
# Text(0, 0.5, 'Character Mass')

# %%
x_values = no_jabba_mass_df["Height"]
y_values = no_jabba_mass_df["Mass"]
plt.scatter(x_values, y_values)
plt.grid()
plt.title("Character Height vs Mass")
plt.xlabel("Character Height")
plt.ylabel("Character Mass")
# Out:
# Text(0, 0.5, 'Character Mass')

# %%
plt.hist(clean_characters_df["Height"])
plt.title("Star Wars Character Height Distribution")
plt.xlabel("Character Height (arbitratry units)")
plt.ylabel("Counts")
print(sts.normaltest(clean_characters_df["Height"].sample(21)))
sd_numpy = np.std(clean_characters_df["Height"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
var_numpy = np.var(clean_characters_df["Height"],ddof = 0)
print(f"The population variance using the NumPy module is {var_numpy}")
# Out:
# NormaltestResult(statistic=7.117745941252026, pvalue=0.028470894173215692)
# The population standard deviation using the NumPy module is 35.23421041336148
# The population variance using the NumPy module is 1241.4495834530308

# %%
plt.hist(clean_characters_df["Height"])
plt.title("Star Wars Character Height Distribution")
plt.xlabel("Character Height (arbitratry units)")
plt.ylabel("Counts")
print(sts.normaltest(clean_characters_df["Height"].sample(21)))
sd_numpy = np.std(clean_characters_df["Height"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
var_numpy = np.var(clean_characters_df["Height"],ddof = 0)
print(f"The population variance using the NumPy module is {var_numpy}")
# Calculate the 68-95-99.7 rule using the standard deviation
mean_numpy = np.mean(clean_characters_df["Height"])
print(f"The mean height of Star Wars characters is {mean_numpy}")
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,3)} and {round(mean_numpy+sd_numpy,3)}")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,3)} and {round(mean_numpy+2*sd_numpy,3)}")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,3)} and {round(mean_numpy+3*sd_numpy,3)}")
# Out:
# NormaltestResult(statistic=21.2383530285869, pvalue=2.4442759660732804e-05)
# The population standard deviation using the NumPy module is 35.23421041336148
# The population variance using the NumPy module is 1241.4495834530308
# The mean height of Star Wars characters is 174.35593220338984
# Roughly 68% of the data is between 139.122 and 209.59
# Roughly 95% of the data is between 103.888 and 244.824
# Roughly 99.7% of the data is between 68.653 and 280.059

# %%
plt.hist(clean_characters_df["Mass"])
plt.title("Star Wars Character Mass Distribution")
plt.xlabel("Character Mass (arbitratry units)")
plt.ylabel("Counts")
print(sts.normaltest(clean_characters_df["Mass"].sample(21)))
sd_numpy = np.std(clean_characters_df["Mass"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
var_numpy = np.var(clean_characters_df["Mass"],ddof = 0)
print(f"The population variance using the NumPy module is {var_numpy}")
# Out:
# NormaltestResult(statistic=53.01230182926008, pvalue=3.079817066716892e-12)
# The population standard deviation using the NumPy module is 168.01494796770845
# The population variance using the NumPy module is 28229.02274059178

# %%
# Calculate the 68-95-99.7 rule using the standard deviation
mean_numpy = np.mean(clean_characters_df["Mass"])
print(f"The mean mass of Star Wars characters is {mean_numpy}")
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,3)} and {round(mean_numpy+sd_numpy,3)}")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,3)} and {round(mean_numpy+2*sd_numpy,3)}")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,3)} and {round(mean_numpy+3*sd_numpy,3)}")
# Out:
# The mean mass of Star Wars characters is 97.31186440677965
# Roughly 68% of the data is between -70.703 and 265.327
# Roughly 95% of the data is between -238.718 and 433.342
# Roughly 99.7% of the data is between -406.733 and 601.357

# %%
plt.hist(no_jabba_mass_df["Mass"])
plt.title("Star Wars Character Mass Distribution No Jabba")
plt.xlabel("Character Mass (arbitratry units)")
plt.ylabel("Counts")
print(sts.normaltest(no_jabba_mass_df["Mass"].sample(21)))
sd_numpy = np.std(no_jabba_mass_df["Mass"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
var_numpy = np.var(no_jabba_mass_df["Mass"],ddof = 0)
print(f"The population variance using the NumPy module is {var_numpy}")
# Out:
# NormaltestResult(statistic=0.5590196325339359, pvalue=0.7561543051662087)
# The population standard deviation using the NumPy module is 28.99924083634645
# The population variance using the NumPy module is 840.9559690844234

# %%
# Calculate the 68-95-99.7 rule using the standard deviation
mean_numpy = np.mean(no_jabba_mass_df["Mass"])
print(f"The mean mass of Star Wars characters is {mean_numpy}")
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,3)} and {round(mean_numpy+sd_numpy,3)}")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,3)} and {round(mean_numpy+2*sd_numpy,3)}")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,3)} and {round(mean_numpy+3*sd_numpy,3)}")
# Out:
# The mean mass of Star Wars characters is 75.5758620689655
# Roughly 68% of the data is between 46.577 and 104.575
# Roughly 95% of the data is between 17.577 and 133.574
# Roughly 99.7% of the data is between -11.422 and 162.574
